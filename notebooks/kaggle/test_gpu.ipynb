# %%
import tensorflow as tf

cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(32, 32, 3),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=5, batch_size=64)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step
# 2025-04-09 01:04:28.294900: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2025-04-09 01:04:28.294962: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2025-04-09 01:04:28.294968: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744157068.295023  107902 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1744157068.295102  107902 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/5
# 2025-04-09 01:04:35.334482: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 273s 305ms/step - accuracy: 0.0507 - loss: 5.0490
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 235s 300ms/step - accuracy: 0.0930 - loss: 4.5802
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 231s 296ms/step - accuracy: 0.1381 - loss: 3.9056
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 234s 299ms/step - accuracy: 0.1722 - loss: 3.6815
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 236s 302ms/step - accuracy: 0.2049 - loss: 3.4803
